# %% [markdown]
# Ebay Car Sales Data

# %%
import pandas as pd
import numpy as np
autos = pd.read_csv(r"C:\Users\moham\Documents\Documents\DataQuest\Ebay Project\autos.csv", encoding="Windows-1252", nrows=50000)

# %%
autos.isnull().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5160
# yearOfRegistration        0
# gearbox                2721
# powerPS                   0
# model                  2759
# kilometer                 0
# monthOfRegistration       0
# fuelType               4610
# brand                     0
# notRepairedDamage      9709
# dateCreated               0
# nrOfPictures              0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %% [markdown]
# The dataset contains 20 columns, most of which are strings.
# Some columns have null values, but none have more than ~20% null values.
# The column names use camelcase instead of Python's preferred snakecase, which means we can't just replace spaces with underscores.

# %%
cols = ["date_crawled", "name", "seller", "offer_type", "dollar_price", "ab_test",
        "vehicle_type", "registration_year", "gearbox", "power_ps", "model",
       "kilometer", "registration_month", "fuel_type", "brand", "unrepaired_damage",
        "ad_created", "pictures_number", "postal_code",  "last_seen_online"]
autos.columns = cols
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'dollar_price',
#        'ab_test', 'vehicle_type', 'registration_year', 'gearbox', 'power_ps',
#        'model', 'kilometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'pictures_number', 'postal_code',
#        'last_seen_online'],
#       dtype='object')

# %%
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    dollar_price ab_test vehicle_type  registration_year    gearbox  power_ps  \
# 0           480    test          NaN               1993    manuell         0
# 1         18300    test        coupe               2011    manuell       190
# 2          9800    test          suv               2004  automatik       163
# 3          1500    test   kleinwagen               2001    manuell        75
# 4          3600    test   kleinwagen               2008    manuell        69
#
#    model  kilometer  registration_month fuel_type       brand  \
# 0   golf     150000                   0    benzin  volkswagen
# 1    NaN     125000                   5    diesel        audi
# 2  grand     125000                   8    diesel        jeep
# 3   golf     150000                   6    benzin  volkswagen
# 4  fabia      90000                   7    diesel       skoda
#
#   unrepaired_damage           ad_created  pictures_number  postal_code  \
# 0               NaN  2016-03-24 00:00:00                0        70435
# 1                ja  2016-03-24 00:00:00                0        66954
# 2               NaN  2016-03-14 00:00:00                0        90480
# 3              nein  2016-03-17 00:00:00                0        91074
# 4              nein  2016-03-31 00:00:00                0        60437
#
#       last_seen_online
# 0  2016-04-07 03:16:57
# 1  2016-04-07 01:46:50
# 2  2016-04-05 12:47:46
# 3  2016-03-17 17:40:17
# 4  2016-04-06 10:17:21

# %%
print(autos["pictures_number"].sum())
print(autos["ab_test"].unique())
print(autos["offer_type"].unique())
autos.drop(["pictures_number", "ab_test", "offer_type", "seller"], axis=1, inplace=True)
# Out:
# 0
# ['test' 'control']
# ['Angebot' 'Gesuch']

# %% [markdown]
# Based on the information we got from the data within each column, we decide to delete the following ones:
#  - pictures_number because all  values are equal to zero
#  - ab_test takes two different values: 'test' and 'control' that are not relevant for our analysis
#  - offer_type takes two different values 'Angebot' and 'Gesuch' that are not relevant for our analysis
#  - seller takes only one value

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# dollar_price          50000 non-null int64
# vehicle_type          44840 non-null object
# registration_year     50000 non-null int64
# gearbox               47279 non-null object
# power_ps              50000 non-null int64
# model                 47241 non-null object
# kilometer             50000 non-null int64
# registration_month    50000 non-null int64
# fuel_type             45390 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40291 non-null object
# ad_created            50000 non-null object
# postal_code           50000 non-null int64
# last_seen_online      50000 non-null object
# dtypes: int64(6), object(10)
# memory usage: 6.1+ MB

# %%
autos.describe()
# Out:
#        dollar_price  registration_year      power_ps      kilometer  \
# count  5.000000e+04       50000.000000  50000.000000   50000.000000
# mean   6.860062e+03        2004.829980    113.669360  125542.000000
# std    1.051966e+05         100.099844    129.459112   40066.523964
# min    0.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.150000e+03        1999.000000     69.000000  100000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.234568e+07        9999.000000  10520.000000  150000.000000
#
#        registration_month   postal_code
# count        50000.000000  50000.000000
# mean             5.740280  50742.358300
# std              3.715667  25886.169436
# min              0.000000   1067.000000
# 25%              3.000000  30419.000000
# 50%              6.000000  49580.500000
# 75%              9.000000  71640.000000
# max             12.000000  99996.000000

# %% [markdown]
# Based on min and max values of numerical data above, we notice that we can reduce the memory usage by storing the data in more optimal types.

# %%
autos.dollar_price = autos.dollar_price.astype(np.uint32)
autos.kilometer = autos.kilometer.astype(np.uint32)
autos.power_ps = autos.power_ps.astype(np.uint16)
autos.registration_month = autos.registration_month.astype(np.uint8)
autos.registration_year = autos.registration_year.astype(np.uint16)
autos.postal_code = autos.postal_code.astype(np.uint32)

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# dollar_price          50000 non-null uint32
# vehicle_type          44840 non-null object
# registration_year     50000 non-null uint16
# gearbox               47279 non-null object
# power_ps              50000 non-null uint16
# model                 47241 non-null object
# kilometer             50000 non-null uint32
# registration_month    50000 non-null uint8
# fuel_type             45390 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40291 non-null object
# ad_created            50000 non-null object
# postal_code           50000 non-null uint32
# last_seen_online      50000 non-null object
# dtypes: object(10), uint16(2), uint32(3), uint8(1)
# memory usage: 4.6+ MB

# %% [markdown]
# We then reduced the memory usage by 1.5 MB out of 6.1 MB, i.e. 25%, just by optimizing the types of numerical data for 50,000 rows.

# %%
print(autos.dollar_price.value_counts().head())
print(autos.dollar_price.unique().shape)
# Out:
# 0       1461
# 500      789
# 1500     718
# 1000     618
# 1200     599
# Name: dollar_price, dtype: int64
# (2381,)

# %%
c_dollar_prices = autos.dollar_price.copy()
s_dollar_prices = c_dollar_prices.sort_values(ascending=False)
s_dollar_prices.index = autos.index
print(s_dollar_prices.head(1))
# Out:
# 0    12345678
# Name: dollar_price, dtype: uint32

# %%
v_dollar_prices = autos[autos["dollar_price"] > 100000].copy()
v_dollar_prices.sort_values(by=['dollar_price'], ascending=False, inplace=True)
v_dollar_prices.head(20)
# Out:
#               date_crawled                                               name  \
# 39625  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 20746  2016-03-08 15:54:52                                 Golf3_Schlachtfest
# 14663  2016-04-03 06:03:56                         Tausch_moeglich_Polo_vw_n9
# 21467  2016-03-19 19:45:02  Porsche_911_911R_1_of_20_ORIGINAL_R_nur_798KG!...
# 41980  2016-03-11 09:37:17                                      Maserati_MC12
# 45055  2016-04-02 00:06:21  Ferrari_LaFerrari_Deutsche_Auslieferung._A_Cel...
# 20143  2016-03-18 00:55:53                         Porsche_911R_Einer_von_911
# 45833  2016-03-15 10:53:11                            Porsche_911_Turbo__930_
# 16889  2016-03-15 16:45:45                   Ford_Mondeo_Kombi_TÜV_abgelaufen
# 38445  2016-03-21 19:53:52                                      2_VW_Busse_T3
# 26327  2016-03-21 19:43:54                                      Porsche_911_R
# 1846   2016-03-10 22:47:05  BMW_M1_Museumsfahrzeug_Neuwagenzustand_Glossy_...
# 10649  2016-04-05 09:36:18                      Porsche_996_GT2_MK2_Clubsport
# 29866  2016-03-21 11:50:40                                    Porsche_997_GT2
# 20818  2016-03-14 13:56:15  Porsche_991_Carrera_S__50_Jahre_911___X51__430...
# 28988  2016-03-21 10:50:12                                        Porsche_997
# 46503  2016-03-09 00:55:57                                        Porsche_911
# 13302  2016-03-20 21:49:18                            Porsche_911_Targa_4_GTS
# 15335  2016-03-27 12:46:46                        Porsche_911_Speedster_breit
# 4359   2016-03-27 23:48:22                               Mercedes_Benz_SL_280
#
#        dollar_price vehicle_type  registration_year    gearbox  power_ps  \
# 39625      12345678          NaN               2018    manuell        95
# 20746      12345678          NaN               1995        NaN         0
# 14663      11111111        coupe               2003    manuell        64
# 21467       9999999        coupe               1967    manuell       215
# 41980       2995000        coupe               2005        NaN       630
# 45055       2795000        coupe               2016        NaN       963
# 20143       1250000        coupe               2016    manuell       500
# 45833       1000000        coupe               1981    manuell       300
# 16889       1000000        kombi               1998        NaN         0
# 38445        999999          bus               1981    manuell        70
# 26327        600000        coupe               2016    manuell       500
# 1846         579000        coupe               1980    manuell       277
# 10649        420000        coupe               2004    manuell       483
# 29866        245000        coupe               2008    manuell       530
# 20818        225000        coupe               2014  automatik       430
# 28988        220000        coupe               2008    manuell       415
# 46503        199900       cabrio               1972    manuell       207
# 13302        192500       cabrio               2015  automatik       430
# 15335        189000       cabrio               1989    manuell       231
# 4359         185000       cabrio               1971  automatik       170
#
#              model  kilometer  registration_month fuel_type           brand  \
# 39625          v40     150000                   6       NaN           volvo
# 20746          NaN     150000                   0       NaN      volkswagen
# 14663         polo     150000                   2    benzin      volkswagen
# 21467          911      50000                  10    benzin         porsche
# 41980          NaN       5000                   7    benzin  sonstige_autos
# 45055          NaN       5000                   3       NaN  sonstige_autos
# 20143          911       5000                   3    benzin         porsche
# 45833          911     150000                   1    benzin         porsche
# 16889       mondeo     150000                   0    benzin            ford
# 38445  transporter     150000                   1    benzin      volkswagen
# 26327          911       5000                   3    benzin         porsche
# 1846        andere      20000                  12    benzin             bmw
# 10649          911      50000                   4    benzin         porsche
# 29866          911      10000                   1    benzin         porsche
# 20818          911      10000                   1    benzin         porsche
# 28988          911      30000                   7    benzin         porsche
# 46503          911      10000                   4    benzin         porsche
# 13302          911       5000                   4    benzin         porsche
# 15335          911      80000                   6    benzin         porsche
# 4359            sl       5000                   7    benzin   mercedes_benz
#
#       unrepaired_damage           ad_created  postal_code     last_seen_online
# 39625              nein  2016-03-08 00:00:00        14542  2016-04-06 23:17:31
# 20746               NaN  2016-03-08 00:00:00        18516  2016-03-17 16:15:43
# 14663               NaN  2016-04-03 00:00:00        46535  2016-04-07 10:16:51
# 21467              nein  2016-03-19 00:00:00        70435  2016-04-01 10:45:30
# 41980              nein  2016-03-11 00:00:00        74232  2016-04-06 21:47:44
# 45055              nein  2016-04-01 00:00:00        60435  2016-04-03 14:32:00
# 20143              nein  2016-03-17 00:00:00        70435  2016-03-20 04:48:27
# 45833              nein  2016-03-15 00:00:00        10969  2016-03-22 09:18:05
# 16889                ja  2016-03-15 00:00:00        26607  2016-03-15 16:45:45
# 38445               NaN  2016-03-21 00:00:00        99880  2016-03-28 17:18:28
# 26327              nein  2016-03-21 00:00:00        76275  2016-03-21 19:43:54
# 1846               nein  2016-03-10 00:00:00        60435  2016-03-23 10:45:27
# 10649              nein  2016-04-05 00:00:00        81669  2016-04-07 12:15:38
# 29866              nein  2016-03-21 00:00:00        80999  2016-04-06 06:45:13
# 20818              nein  2016-03-14 00:00:00        78126  2016-04-05 15:15:57
# 28988              nein  2016-03-21 00:00:00        69198  2016-04-06 04:46:14
# 46503              nein  2016-03-09 00:00:00        53639  2016-04-07 04:47:01
# 13302              nein  2016-03-20 00:00:00        36043  2016-04-07 07:16:29
# 15335              nein  2016-03-27 00:00:00        82064  2016-04-07 08:16:12
# 4359               nein  2016-03-27 00:00:00        92318  2016-04-06 02:15:21

# %% [markdown]
# We consider as outliers all the rows with a dollar_price inferior to $100 and superior to $80000.

# %%
autos = autos[autos["dollar_price"].between(100,80000)]
v_dollar_prices = autos[autos["dollar_price"] >= 50000].copy()
v_dollar_prices.sort_values(by=['dollar_price'], ascending=False, inplace=True)
v_dollar_prices.head(20)
# Out:
#               date_crawled                                               name  \
# 30656     c_klasse      40000                   8    benzin   mercedes_benz
# 8610           911      40000                  11    benzin         porsche
# 3883           911      50000                   2    benzin         porsche
# 3735           NaN      70000                   2    benzin  sonstige_autos
# 42321          911      30000                   5    benzin         porsche
# 31616  transporter      10000                   8       NaN      volkswagen
# 37012       andere      90000                   8    benzin         renault
# 18892          911      40000                   1    benzin         porsche
# 20982          911      50000                   9    benzin         porsche
# 48688       andere       5000                   1    diesel   mercedes_benz
# 18678     g_klasse      60000                   7    diesel   mercedes_benz
# 31975      cayenne      10000                  10       NaN         porsche
# 12982          NaN      50000                   9    benzin  sonstige_autos
#
#       unrepaired_damage           ad_created  postal_code     last_seen_online
# 8641               nein  2016-03-24 00:00:00        68163  2016-04-06 21:46:51
# 14318              nein  2016-03-14 00:00:00        57462  2016-04-05 11:50:32
# 45993              nein  2016-03-28 00:00:00        22587  2016-04-06 10:17:53
# 34021              nein  2016-03-20 00:00:00        59821  2016-04-02 21:20:41
# 30725              nein  2016-03-12 00:00:00        32423  2016-03-16 23:47:17
# 10194              nein  2016-03-24 00:00:00        47918  2016-03-27 13:45:48
# 24696              nein  2016-03-12 00:00:00        66119  2016-04-06 23:45:17
# 30656              nein  2016-03-08 00:00:00        16230  2016-04-06 01:46:08
# 8610               nein  2016-03-09 00:00:00        26842  2016-03-11 19:20:42
# 3883               nein  2016-03-23 00:00:00        36286  2016-04-06 07:17:13
# 3735               nein  2016-03-19 00:00:00        64546  2016-04-06 04:45:38
# 42321              nein  2016-03-31 00:00:00        72393  2016-04-06 01:16:41
# 31616              nein  2016-04-02 00:00:00        44869  2016-04-06 05:15:54
# 37012              nein  2016-04-03 00:00:00        33335  2016-04-07 12:44:52
# 18892              nein  2016-03-07 00:00:00        60385  2016-04-05 12:45:26
# 20982              nein  2016-03-11 00:00:00        45468  2016-03-22 06:47:10
# 48688              nein  2016-03-21 00:00:00        10715  2016-03-31 11:16:54
# 18678              nein  2016-03-15 00:00:00        97252  2016-03-28 13:44:52
# 31975              nein  2016-03-28 00:00:00        63110  2016-04-06 23:15:52
# 12982              nein  2016-03-20 00:00:00        66625  2016-04-06 08:46:38

# %%
autos.loc[(autos["vehicle_type"] == "kombi") & (autos["dollar_price"] > 50000), "dollar_price"]
# Out:
# 1284     51000
# 4631     55999
# 7057     53900
# 15348    59000
# 15999    51593
# 17936    52999
# 36614    50699
# 43724    53900
# 46121    60000
# 47733    69990
# Name: dollar_price, dtype: uint32

# %%
autos.index
# Out:
# Int64Index([    0,     1,     2,     3,     4,     5,     6,     8,     9,
#                10,
#             ...
#             49990, 49991, 49992, 49993, 49994, 49995, 49996, 49997, 49998,
#             49999],
#            dtype='int64', length=48137)

# %%
autos.index = range(48137)

# %% [markdown]
# View of the various vehicle and fuel types

# %%
print(autos['vehicle_type'].unique(), autos['fuel_type'].unique())
# Out:
# [nan 'coupe' 'suv' 'kleinwagen' 'limousine' 'cabrio' 'bus' 'kombi'
#  'andere'] ['benzin' 'diesel' nan 'lpg' 'andere' 'hybrid' 'cng' 'elektro']

# %% [markdown]
# We use a dictionary and the map function to convert vehicle and fuel types from German to English

# %%
mapping_vehicle_type = {
    'coupe': 'coupé',
    'kleinwagen': 'small car',
    'kombi': 'station wagon',
    'cabrio': 'convertible',
    'andere': 'other',
    'hybrid':'hybrid',
    'limousine':'limousine',
    'bus':'bus'
                        }

mapping_fuel_type = {
    'benzin': 'gasoline',
    'diesel': 'diesel',
    'lpg': 'liquefied petroleum gas',
    'andere': 'other',
    'cng': 'compressed natural gas',
    'elekto':'electric'
                    }

autos['vehicle_type'] = autos['vehicle_type'].map(mapping_vehicle_type)
autos['fuel_type'] = autos['fuel_type'].map(mapping_fuel_type)

# %%
autos[autos['model'].isnull()]
# Out:
#               date_crawled                                               name  \
# 1      2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 80     2016-04-03 12:56:45                     Bastler_Fahrzeug_mit_Rest_Tuev
# 133    2016-03-27 20:51:23            Audi_80_5_Zylinder_b4_liebhaberfahrzeug
# 150    2016-03-27 20:47:22                            POLO_1.2_KILIMA_WIE_NEU
# 157    2016-03-19 19:49:15                                         is_ales_ok
# 158    2016-03-28 10:50:04                             VW_Caddy_Lkw_Zulassung
# 183    2016-03-16 15:51:08                            BMW_530xd_e60_EZ10/2008
# 191    2016-03-27 12:47:45                 VW_Polo_Coupe_86c_1990Bj._125193km
# 259    2016-04-04 09:49:59                       Mitsubishi_Colt_Tuev_07/2016
# 275    2016-03-29 23:38:02                     Audi_80_coupe_top_gepflegt_2_0
# 308    2016-03-21 14:38:37                    Tauache_90ccm_roller_gegen_auto
# 310    2016-03-13 13:38:54                  Biete_BMW_318_i_Kombi_auch_Tausch
# 354    2016-03-08 08:57:34                                  Peugeot_107_Klima
# 362    2016-03-23 23:57:07                   Peugeot__F__206_mit_Motorschaden
# 365    2016-03-11 21:49:52                                       Corvette_Z06
# 414    2016-03-26 21:49:45         Alfa_Giulietta_2.0_JTDm_mit_QV_Ausstattung
# 432    2016-03-20 20:45:27                                       Microcar_MC1
# 436    2016-03-27 18:43:25                            Passat_fuer_ausschalten
# 437    2016-04-02 17:54:29                           VW_Touran_1.9_TDI_United
# 444    2016-03-24 16:46:05                                 VW_golf_1_4_4_tuer
# 544    2016-03-15 17:43:21                                        Top_zustand
# 590    2016-03-10 18:45:10         Peugeot_206cc_Quiksilver_BJ_2005_95.000_km
# 620    2016-03-12 17:50:58  Preis_nur_bis_morgen_14Uhr:_Schoener_Polo_HU/A...
# 633    2016-03-27 09:56:27   BMW_E_46_Cabrio__Black_Saphir_Metallic__Facelift
# 647    2016-03-27 22:52:02                          Audi_A8_d2_4_2Ltr_Quattro
# 652    2016-03-07 09:52:06           Mitsubishi_carisma_1.8gdi_klima_tuev_neu
# 653    2016-03-30 11:55:46                                 Oldsmobile_Cutlass
# 665    2016-04-01 15:56:27        Dodge_RAM_1500_SLT_5_9l_V8_4X4_Benzin_/_Gas
# 673    2016-03-17 14:56:29           C_220CDI_KOMBI_TÜV_NEU_DPF_MOPF_FACELIFT
# 437            5800            bus               2007    manuell       105
# 444            1950            NaN               2017    manuell         0
# 544            2600            NaN               2005        NaN         0
# 590            3800    convertible               2005    manuell       109
# 620            1600      small car               2002    manuell        64
# 633            7400    convertible               2003  automatik       192
# 647            2200      limousine               1995  automatik       299
# 652            1900      limousine               2000    manuell       125
# 653           15000          coupé               1971        NaN         0
# 665            9900            NaN               2000  automatik       250
# 673            5900  station wagon               2004    manuell       150
# 693            5500      small car               2007    manuell        75
# ...             ...            ...                ...        ...       ...
# 47450         16900            NaN               2005        NaN       500
# 47475         12000      limousine               2003  automatik       218
# 47506          1000      small car               1998    manuell        75
# 47518          1749      limousine               2001    manuell        60
# 47539           120            NaN               2016    manuell         0
# 47547          1300  station wagon               1998    manuell       115
# 47580           200      limousine               2005    manuell         0
# 47602         12900      limousine               2012  automatik        99
# 47604          4500            NaN               2017    manuell         0
# 47606          1500      limousine               2004    manuell         0
# 47621          1500  station wagon               2003    manuell       110
# 47679          6490      limousine               2005        NaN         0
# 47700          3200            NaN               2016    manuell        68
# 47744          3200      limousine               2003    manuell       150
# 47769          1000            NaN               2017        NaN         0
# 47780          1300            NaN               2000        NaN         0
# 47800           150      limousine               1994    manuell        60
# 47806           350      small car               2000    manuell        50
# 47807          1250            NaN               2017    manuell       113
# 47809          1500            NaN               1995        NaN         0
# 47811         11000      limousine               2005  automatik       249
# 47860          7500      limousine               2003  automatik         0
# 47869           500            NaN               2016    manuell         0
# 47875          1000      limousine               1996  automatik         0
# 47882          1399  station wagon               1996    manuell        75
# 47937          5000            NaN               2018    manuell       143
# 48015           700      small car               1999    manuell        75
# 48027           400          coupé               1995    manuell       130
# 48028          1600      limousine               2010    manuell         0
# 48046          1500            bus               2001    manuell       105
#
#       model  kilometer  registration_month                fuel_type  \
# 1       NaN     125000                   5                   diesel
# 80      NaN     150000                   3                      NaN
# 133     NaN     150000                   0                      NaN
# 150     NaN      20000                   5                 gasoline
# 157     NaN     150000                   0                 gasoline
# 158     NaN     150000                   9                   diesel
# 183     NaN     150000                   0                      NaN
# 191     NaN     150000                   0                 gasoline
# 259     NaN     150000                   3                 gasoline
# 275     NaN     150000                   8                      NaN
# 308     NaN      10000                   0                      NaN
# 310     NaN     150000                   6                 gasoline
# 354     NaN      40000                  12                      NaN
# 362     NaN     150000                   5                 gasoline
# 365     NaN      10000                   6                 gasoline
# 414     NaN      60000                  11                   diesel
# 432     NaN      70000                   5                   diesel
# 436     NaN     150000                  10                      NaN
# 437     NaN     150000                  11                   diesel
# 444     NaN     150000                   7                 gasoline
# 544     NaN     125000                   0                      NaN
# 590     NaN     100000                  12                 gasoline
# 620     NaN     150000                   2                 gasoline
# 633     NaN     150000                   8                      NaN
# 647     NaN     150000                   5                      NaN
# 652     NaN     150000                   5                 gasoline
# 653     NaN       5000                   4                      NaN
# 665     NaN     150000                   4  liquefied petroleum gas
# 673     NaN     150000                   2                   diesel
# 693     NaN     100000                  10                 gasoline
# ...     ...        ...                 ...                      ...
# 47450   NaN     150000                   0                      NaN
# 47475   NaN     150000                  11                      NaN
# 47506   NaN     150000                   8                 gasoline
# 47518   NaN     150000                   5                 gasoline
# 47539   NaN     150000                   0                 gasoline
# 47547   NaN     150000                   0                      NaN
# 47580   NaN     150000                   1                 gasoline
# 47602   NaN     100000                   6                      NaN
# 47604   NaN      50000                   0                      NaN
# 47606   NaN     150000                   2  liquefied petroleum gas
# 47621   NaN     150000                  12                   diesel
# 47679   NaN     150000                  12                   diesel
# 47700   NaN     125000                   5                      NaN
# 47744   NaN     150000                  12                   diesel
# 47769   NaN     150000                   1                      NaN
# 47780   NaN      20000                   0                      NaN
# 47800   NaN     150000                   3                 gasoline
# 47806   NaN     150000                   3                 gasoline
# 47807   NaN     150000                  10                 gasoline
# 47809   NaN     150000                   0                 gasoline
# 47811   NaN      90000                  10                 gasoline
# 47860   NaN     150000                   0                   diesel
# 47869   NaN     150000                   0                 gasoline
# 47875   NaN       5000                   1                 gasoline
# 47882   NaN     150000                   3                 gasoline
# 47937   NaN     150000                  10                      NaN
# 48015   NaN     100000                   5                 gasoline
# 48027   NaN     150000                   0                      NaN
# 48028   NaN      80000                   4                 gasoline
# 48046   NaN     150000                   7                 gasoline
#
#                 brand unrepaired_damage           ad_created  postal_code  \
# 1                audi                ja  2016-03-24 00:00:00        66954
# 80               fiat                ja  2016-04-03 00:00:00        45665
# 133              audi              nein  2016-03-27 00:00:00        38709
# 150        volkswagen              nein  2016-03-27 00:00:00        89077
# 157           renault              nein  2016-03-19 00:00:00        26969
# 158        volkswagen               NaN  2016-03-28 00:00:00        99086
# 183               bmw              nein  2016-02-12 00:00:00        95131
# 191        volkswagen               NaN  2016-03-27 00:00:00        83317
# 259        mitsubishi              nein  2016-04-04 00:00:00        59302
# 275              audi              nein  2016-03-29 00:00:00        32791
# 308    sonstige_autos               NaN  2016-03-21 00:00:00         6493
# 310               bmw              nein  2016-03-13 00:00:00        41199
# 354           peugeot              nein  2016-03-08 00:00:00        24536
# 362           peugeot                ja  2016-03-23 00:00:00        84579
# 365    sonstige_autos              nein  2016-03-11 00:00:00        79774
# 414        alfa_romeo              nein  2016-03-26 00:00:00        86830
# 432    sonstige_autos              nein  2016-03-20 00:00:00        90562
# 436        volkswagen              nein  2016-03-27 00:00:00        70374
# 437        volkswagen                ja  2016-04-02 00:00:00        31319
# 444        volkswagen              nein  2016-03-24 00:00:00        70376
# 544         chevrolet               NaN  2016-03-15 00:00:00        94315
# 590           peugeot               NaN  2016-03-10 00:00:00        46049
# 620        volkswagen              nein  2016-03-12 00:00:00         4552
# 633               bmw              nein  2016-03-27 00:00:00        71067
# 647              audi                ja  2016-03-27 00:00:00        74182
# 652        mitsubishi              nein  2016-03-07 00:00:00        14943
# 653    sonstige_autos              nein  2016-03-30 00:00:00        51145
# 665    sonstige_autos              nein  2016-04-01 00:00:00        17309
# 673     mercedes_benz              nein  2016-03-17 00:00:00        58089
# 693           renault               NaN  2016-03-12 00:00:00        17034
# 2016-03-11    0.031930
# 2016-03-10    0.031764
# 2016-03-09    0.034526
# 2016-03-08    0.033405
# 2016-03-07    0.034381
# 2016-03-05    0.021792
# Name: ad_created, dtype: float64

# %% [markdown]
# The ads crawled were created between March 2015, 20th and April 2016, 7th. We notice that 93% of them were created between March 2016, 5th and April 2016, 7th. It's in line with the dates the website was crawled. We can infer that an ad has a lifetime of approximately one month. We could for example neglect the ads created before March 2016 depending on our analysis.

# %%
autos['last_seen_online'].value_counts(normalize=True).sort_index(ascending=False)
# Out:
# 2016-04-07    0.133328
# 2016-04-06    0.218855
# 2016-04-05    0.127386
# 2016-04-04    0.025760
# 2016-04-03    0.024783
# 2016-04-02    0.026051
# 2016-04-01    0.024139
# 2016-03-31    0.024181
# 2016-03-30    0.022872
# 2016-03-29    0.023267
# 2016-03-28    0.022083
# 2016-03-27    0.016308
# 2016-03-26    0.016474
# 2016-03-25    0.018759
# 2016-03-24    0.019320
# 2016-03-23    0.018572
# 2016-03-22    0.019652
# 2016-03-21    0.019881
# 2016-03-20    0.020068
# 2016-03-19    0.015830
# 2016-03-18    0.006585
# 2016-03-17    0.028481
# 2016-03-16    0.016121
# 2016-03-15    0.015435
# 2016-03-14    0.011717
# 2016-03-13    0.007832
# 2016-03-12    0.023329
# 2016-03-11    0.013732
# 2016-03-10    0.011093
# 2016-03-09    0.010595
# 2016-03-08    0.007915
# 2016-03-07    0.005027
# 2016-03-06    0.003511
# 2016-03-05    0.001059
# Name: last_seen_online, dtype: float64

# %% [markdown]
# ~50% of the cars were last seen online during the three last days the website was crawled. We can infer that the crawler needs to put a value in the last_seen_online column even if the ad is still active. If we have to analyse the car sales, we will then exclude these three days from the analysis.

# %% [markdown]
# Let's check the consistency of the data and the reliability of the crawler by comparing the date the ad was created and the last time it was seen online:

# %%
(autos['ad_created'] <= autos['last_seen_online']).all()
# Out:
# True

# %% [markdown]
# All the ads were created before they were last seen online, then the crawling worked properly.

# %%
a = (autos['registration_year'] > 2016)
b = a[a == True]
b.count()
# Out:
# 1896

# %% [markdown]
# Some of the data in the registration_year column are wrong, a registration superior to April 2016 is not possible based on the date of the latest crawling. Given  the important number of cars between 2017 and 2019, we could change these values to 2016 for example.  We can consider that a registration before 1945 is also an error. Even if some ads might be right, there is a high probabilty to find outliers.

# %%
autos['registration_year'].value_counts().sort_index(ascending=False)
autos.loc[autos["registration_year"].between(2017,2018), "registration_year"] = 2016
autos['registration_year'].value_counts().sort_index(ascending=False)
# Out:
# 9999       4
# 9000       1
# 8888       1
# 6000       1
# 5300       1
# 4100       1
# 3200       1
# 3000       1
# 2900       1
# 2200       1
# 2066       1
# 2019       2
# 2016    3086
# 2015     365
# 2014     652
# 2013     863
# 2012    1305
# 2011    1598
# 2010    1608
# 2009    2068
# 2008    2170
# 2007    2358
# 2006    2676
# 2005    2866
# 2004    2603
# 2003    2648
# 2002    2505
# 2001    2710
# 2000    3073
# 1999    2902
#         ...
# 1966      24
# 1965      13
# 1964       7
# 1963       5
# 1962       3
# 1961       9
# 1960      13
# 1959       3
# 1958       4
# 1957       1
# 1956       2
# 1955       2
# 1954       2
# 1953       1
# 1951       3
# 1949       1
# 1945       1
# 1941       2
# 1940       2
# 1937       4
# 1936       1
# 1935       1
# 1933       1
# 1929       1
# 1925       1
# 1910       5
# 1800       1
# 1500       1
# 1234       1
# 1000       1
# Name: registration_year, Length: 92, dtype: int64

# %%
(~autos["registration_year"].between(1945,2016)).sum() / autos.shape[0]
# Out:
# 0.0007894135488293828

# %%
# Many ways to select rows in a dataframe that fall within a value range for a column.
# Using `Series.between()` is one way.
autos = autos[autos["registration_year"].between(1945,2016)]
autos["registration_year"].value_counts(normalize=True).head(10)
# Out:
# 2016    0.064159
# 2000    0.063889
# 1999    0.060334
# 2005    0.059585
# 2001    0.056342
# 2006    0.055635
# 2003    0.055053
# 2004    0.054118
# 2002    0.052080
# 2007    0.049024
# Name: registration_year, dtype: float64

# %%
p_brands = autos['brand'].value_counts(normalize=True)
p_brands
# Out:
# volkswagen        0.209547
# bmw               0.109607
# opel              0.107196
# mercedes_benz     0.095698
# audi              0.088838
# ford              0.069128
# renault           0.049564
# peugeot           0.030500
# fiat              0.025780
# seat              0.019834
# skoda             0.016799
# mazda             0.015905
# citroen           0.015239
# smart             0.014429
# nissan            0.013763
# toyota            0.012599
# hyundai           0.009605
# mini              0.009376
# volvo             0.009065
# sonstige_autos    0.008649
# mitsubishi        0.008087
# honda             0.007485
# kia               0.006965
# suzuki            0.006424
# alfa_romeo        0.005988
# porsche           0.005489
# chevrolet         0.004865
# chrysler          0.003701
# dacia             0.002432
# land_rover        0.002183
# jeep              0.002121
# subaru            0.002037
# daihatsu          0.001996
# jaguar            0.001746
# trabant           0.001435
# saab              0.001414
# daewoo            0.001372
# rover             0.001227
# lancia            0.001185
# lada              0.000728
# Name: brand, dtype: float64

# %% [markdown]
# To carry out the analysis of the car price within each brand, we are going to consider only brands with more than 1% of data, it represents 16 brands. We need enough data to perform this kind of analysis to avoid mistaking due to an inconsistency of the data. A wrong price has more impact if the number of total prices is low.

# %%
brand_mean_price = {}
brands = p_brands[p_brands > 0.01].index
for b in brands:
    mean_price = int(autos.loc[autos.brand == b, "dollar_price"].mean())
    mean_mileage = int(autos.loc[autos.brand == b, "kilometer"].mean())
    mean_year = int(autos.loc[autos.brand == b, "registration_year"].mean())
    brand_mean_price[b] = [mean_price, mean_mileage, mean_year]
df = pd.DataFrame.from_dict(brand_mean_price, orient='index', columns=['mean_price', 'mean_mileage', 'mean_year'])
df.head()
# Out:
#                mean_price  mean_mileage  mean_year
# volkswagen           5376        128446       2003
# bmw                  8403        133154       2003
# opel                 2949        128794       2002
# mercedes_benz        8266        131067       2002
# audi                 9020        129840       2004

# %% [markdown]
# The mean prices are in line with our knowledge on the brand real prices. The three more expensive brands are respectively Audi, Bmw and Mercedes because of their high standards. More affordable brands like Renault, Fiat, Opel and Peugeot have a cheaper mean price. We could also add the mean year of registration per brand to improve the analysis.
